# %%
! pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 34.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 39.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 12.4 MB/s eta 0:00:00
# ...

# %%
from transformers import GPT2Tokenizer, GPT2Model
from transformers import pipeline

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)

# %%
generator = pipeline('text-generation', model='gpt2')
generator
# Out:
# ...
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
sentence = "Louis is a scientist who likes to punch. What Louis is happy to do is to punch." \
                "Eugene is a waiter who likes to report. What Eugene is happy to do is to report." \
                "Russell is an accountant who likes to eat. What Russell is happy to do is to eat." \
                "Willie is a library assistant who likes to follow. What Willie is happy to do is to follow." \
                "Arthur is a clerk who likes to grow. What Arthur is happy to do is to grow." \
                "Julia is a painter who likes to sing. What Julia is happy to do is to sing." \
                "Sophia is a sign language Interpreter who likes to rest. What Sophia is happy to do is to rest." \
                "Denise is a translator who likes to look. What Denise is happy to do is to look." \
                "Beverly is a farmer who likes to love. What Beverly is happy to do is to love." \
                "Natalie is a director who likes to commit. What Natalie is happy to do is to commit."\
                "Marie is a baker who doesn't like to go. What Marie is happy to do is to"

# %%
sentence = "Louis is a scientist who likes to punch. What Louis is happy to do is to punch." \
                "Natalie is a director who likes to commit. What Natalie is happy to do is to commit."\
                "Marie is a baker who likes to go. What Marie isn't happy to do is to"

# %%
encoded_input = tokenizer(sentence, return_tensors='pt')

size_gen = encoded_input["input_ids"].shape[-1]
generator(sentence, max_length=size_gen+1, num_return_sequences=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Louis is a scientist who likes to punch. What Louis is happy to do is to punch.Natalie is a director who likes to commit. What Natalie is happy to do is to commit.Marie is a baker who likes to go. What Marie isn't happy to do is to go"}]
